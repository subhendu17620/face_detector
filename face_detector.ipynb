# %%
# !wget cb.lk/facemodel
# Out:
# --2019-07-28 14:04:37--  http://cb.lk/facemodel
# Resolving cb.lk (cb.lk)... 159.89.170.74
# Connecting to cb.lk (cb.lk)|159.89.170.74|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cb.lk/facemodel [following]
# --2019-07-28 14:04:38--  https://cb.lk/facemodel
# Connecting to cb.lk (cb.lk)|159.89.170.74|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/s/5o64ru428jlb29g/haarcascade_frontalface_alt.xml?dl=0 [following]
# --2019-07-28 14:04:39--  https://www.dropbox.com/s/5o64ru428jlb29g/haarcascade_frontalface_alt.xml?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/5o64ru428jlb29g/haarcascade_frontalface_alt.xml [following]
# ...

# %%
# !mv facemodel "face_model.xml"

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-51303feb-7f81-4843-b93e-89213542f6d5" name="files[]" multiple disabled />
#      <output id="result-51303feb-7f81-4843-b93e-89213542f6d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image1.jpg to image1.jpg
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('image1.jpg')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x625 at 0x7EFDDD6D4D68>

# %%
face_detector = cv2.CascadeClassifier('face_model.xml')

# %%
faces_detected = face_detector.detectMultiScale(img,1.3,5)
print(faces_detected)
# Out:
# [[464 129  74  74]
#  [826 129  77  77]
#  [634 153  66  66]
#  [ 81 163  74  74]
#  [259 139  74  74]
#  [722 210  73  73]
#  [571 221  77  77]
#  [383 194  85  85]
#  [237 233  80  80]]

# %%
for face in faces_detected:
    
    x,y,w,h = face
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,0),2)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x625 at 0x7EFDDF753C18>

# %% [markdown]
# all codes starting with '!' are linux codes
# ## not work in windows
# try in google colab

# %% [markdown]
# #this xml  will work for front faces only
